# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors

algo = "auto"
met = "euclidean"

# Baca data dari CSV
data = pd.read_csv("resisData3.csv")

# Drop kolom yang tidak diperlukan
data = data.drop(['id', 'kode', 'sumber', 'gambar', 'satuan'], axis=1)
data['jenis_pangan_encoded'] = pd.factorize(data['jenis_pangan'])[0] 

# Ubah nilai yang asalnya ',' menjadi '.'
numeric_cols = [ "jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
    "serat_gram", "abu_gram", "kalsium_mg", "fosfor_mg", "zatbesi_mg", "natrium_mg",
    "kalium_mg", "tembaga_mg", "seng_mg", "retinol_mcg", "thiamin_mg", "riboflavin_mg",
    "niasin_mg", "vitc_mg", "bdd"
]
# numeric_cols = [ "jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
#     "serat_gram", "natrium_mg", "kalium_mg", "bdd"
# ]
# 
print(len(numeric_cols))

data[numeric_cols] = data[numeric_cols].replace({',': '.'}, regex=True)
data[numeric_cols] = data[numeric_cols].astype(float)

# Normalisasi data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data[numeric_cols])

# Menggunakan Nearest Neighbors
model = NearestNeighbors(n_neighbors=6, algorithm=algo, metric=met)
model.fit(data_normalized)

# Fungsi untuk mendapatkan rekomendasi makanan
def get_recommendations(food_names, allergy_list):
    # Cari indeks makanan yang cocok dengan nama makanan yang diberikan
    food_indices = [data[data['nama_bahan'] == food_name].index[0] for food_name in food_names]
    
    print("Makanan tersebut berada di indeks ke-", food_indices)
    
    # Mencari tetangga terdekat
    distances, indices = model.kneighbors(data_normalized[food_indices])
    
    print("distances", distances)
    
    print("indices",indices)
    
    # Mendapatkan nama dan skor kemiripan makanan
    recommendations = []
    jarak = []
    for idx_list, dist_list in zip(indices, distances):
        for idx, dist in zip(idx_list, dist_list):
            if idx not in food_indices:
                recommendations.append(data.iloc[idx]['nama_bahan'])
                jarak.append(dist)
    
    return recommendations[:10], jarak[:10]  # Mengambil 10 teratas

# Contoh penggunaan
allergy_list = ['susu']  # Ganti dengan alergi yang dimiliki user
food_names = ['Ikan tuna']  # Ganti dengan makanan yang dimiliki user
recommendations, jarak = get_recommendations(food_names, allergy_list)
print(f"Rekomendasi makanan {algo} dan {met}:")
for idx, (food, score) in enumerate(zip(recommendations, jarak)):
    print(f"{idx+1}. {food} (distances: {score})")
# Out:
# 21
# Makanan tersebut berada di indeks ke- [134]
# distances [[0.         0.09257137 0.15922799 0.1747251  0.19018326 0.19921554]]
# indices [[134 114 167 137 220  65]]
# Rekomendasi makanan auto dan euclidean:
# 1. ikan mujahir pepes (distances: 0.09257137263844041)
# 2. Ikan salmon (distances: 0.15922798814634506)
# 3. ikan selar kering mentah (distances: 0.17472510164719013)
# 4. takwa (distances: 0.19018325984854434)
# 5. ikan sidat segar (distances: 0.19921553909910875)

# %%
data
# Out:
#                     nama_bahan  air_gram  energi_kal  protein_gram  \
# 0                 abon haruwan      11.6       513.0         23.70
# 1                    abon ikan       6.4       435.0         27.20
# 2       bekicot dendeng mentah       6.7       441.0         48.70
# 3                 belut goreng      11.2       417.0         25.90
# 4           betok wadi masakan      69.2       145.0         16.30
# ...                        ...       ...         ...           ...
# 2624                Oat Pisang       0.0       680.0          2.28
# 2625  Protein Bar Kacang Tanah       0.0       302.0          2.20
# 2626                Klepon Ubi       0.0       522.0          1.01
# 2627               Pancake Oat       0.0       849.0         14.69
# 2628        Sup Pembakar Lemak       0.0       202.0          2.27
#
#       lemak_gram  karbohidrat_gram  serat_gram  abu_gram  kalsium_mg  \
# 0          37.00             21.30         0.0       6.4        25.0
# ...

# %%
import pandas as pd
import numpy as np
# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# Baca data dari CSV
data = pd.read_csv("resisData3.csv")

# Drop kolom yang tidak diperlukan
data = data.drop(['id', 'kode', 'sumber', 'gambar', 'satuan'], axis=1)
data['jenis_pangan_encoded'] = pd.factorize(data['jenis_pangan'])[0]

# Ubah nilai yang asalnya ',' menjadi '.'
numeric_cols = ["jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
                "serat_gram", "abu_gram", "kalsium_mg", "fosfor_mg", "zatbesi_mg", "natrium_mg",
                "kalium_mg", "tembaga_mg", "seng_mg", "retinol_mcg", "thiamin_mg", "riboflavin_mg",
                "niasin_mg", "vitc_mg", "bdd"]

data[numeric_cols] = data[numeric_cols].replace({',': '.'}, regex=True)
data[numeric_cols] = data[numeric_cols].astype(float)

# Normalisasi data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data[numeric_cols])

# Membagi data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(data_normalized, data_normalized, test_size=0.3, random_state=42)

# Melatih model Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Prediksi pada set pengujian
y_pred = model.predict(X_test)

# Menghitung RMSE dan MAE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")

# Fungsi untuk mendapatkan rekomendasi makanan
def get_recommendations(food_names, allergy_list):
    # Cari indeks makanan yang cocok dengan nama makanan yang diberikan
    food_indices = [data[data['nama_bahan'] == food_name].index[0] for food_name in food_names]
    
    print("Makanan tersebut berada di indeks ke-", food_indices)
    
    # Mendapatkan prediksi dari model
    food_features = data_normalized[food_indices]
    predictions = model.predict(food_features)
    
    # Menghitung kemiripan kosinus antara makanan input dan prediksi
    similarities = cosine_similarity(predictions, data_normalized)
    
    # Mendapatkan rekomendasi berdasarkan kemiripan
    recommendations = []
    similarity_scores = []
    for sim in similarities:
        sorted_indices = sim.argsort()[::-1]
        for idx in sorted_indices:
            if idx not in food_indices:
                recommendations.append(data.iloc[idx]['nama_bahan'])
                similarity_scores.append(sim[idx])
    
    return recommendations[:3], similarity_scores[:3]  # Mengambil 30 teratas

# Contoh penggunaan
allergy_list = ['susu']  # Ganti dengan alergi yang dimiliki user
food_names = ['Klapertart']  # Ganti dengan makanan yang dimiliki user
recommendations, similarity_scores = get_recommendations(food_names, allergy_list)
print("Rekomendasi makanan:")
for idx, (food, score) in enumerate(zip(recommendations, similarity_scores)):
    print(f"{idx+1}. {food} (Similarity Score: {score})")
# Out:
# RMSE: 0.039528009485695105
# MAE: 0.013311692069857177
# Makanan tersebut berada di indeks ke- [697]
# Rekomendasi makanan:
# 1. Sariroti sandwich coklat (Similarity Score: 0.9996197045616583)
# 2. Brownies Oat (Similarity Score: 0.9995080659744848)
# 3. Kue Pisang Kukus (Similarity Score: 0.9994319046946704)

# %%
def nutrition_need(umur, tb, bb, aktifitas, kondisi, waktu_makan):
    aktivitas_factor = {
        "Bed Rest": 1.1,
        "bergerak terbatas": 1.2,
        "bisa jalan": 1.3
    }

    if aktifitas not in aktivitas_factor:
        return False

    aktifitas = aktivitas_factor[aktifitas]

    # Calculate BMR and macronutrient needs
    BMR_perempuan = 655 + (9.6 * bb) + (1.8 * tb) - (4.7 * umur)
    total_kalori = BMR_perempuan * aktifitas
    karbohidrat = (0.6 * total_kalori) / 4
    lemak = (0.25 * total_kalori) / 9
    protein = (0.15 * total_kalori) / 4

    batas_atas = {
        'energi_kal': total_kalori,
        'karbohidrat_gram': karbohidrat,
        'lemak_gram': lemak,
        'protein_gram': protein,
        'serat_gram': 0,
        'air_gram': 0,
        'vitc_mg': 0,
        'retinol_mcg': 0,
        'kalsium_mg': 0,
        'fosfor_mg': 0,
        'zatbesi_mg': 0,
        'kalium_mg': 0,
        'natrium_mg': 0,
        'tembaga_mg': 0
    }

    age_based_limits = [
        (11, 12, {'serat_gram': 27, 'air_gram': 1850, 'vitc_mg': 50, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 1250, 'zatbesi_mg': 8, 'kalium_mg': 4400, 'natrium_mg': 1400, 'tembaga_mg': 700}),
        (13, 15, {'serat_gram': 27, 'air_gram': 2100, 'vitc_mg': 65, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 1250, 'zatbesi_mg': 15, 'kalium_mg': 4800, 'natrium_mg': 1500, 'tembaga_mg': 795}),
        (16, 18, {'serat_gram': 29, 'air_gram': 2150, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 1250, 'zatbesi_mg': 15, 'kalium_mg': 5000, 'natrium_mg': 1600, 'tembaga_mg': 890}),
        (19, 29, {'serat_gram': 32, 'air_gram': 2350, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1000, 'fosfor_mg': 700, 'zatbesi_mg': 18, 'kalium_mg': 4700, 'natrium_mg': 1500, 'tembaga_mg': 900}),
        (30, 49, {'serat_gram': 30, 'air_gram': 2350, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1000, 'fosfor_mg': 700, 'zatbesi_mg': 18, 'kalium_mg': 4700, 'natrium_mg': 1500, 'tembaga_mg': 900}),
        (50, 64, {'serat_gram': 25, 'air_gram': 2350, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 700, 'zatbesi_mg': 8, 'kalium_mg': 4700, 'natrium_mg': 1400, 'tembaga_mg': 900}),
        (65, 80, {'serat_gram': 22, 'air_gram': 1550, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 700, 'zatbesi_mg': 8, 'kalium_mg': 4700, 'natrium_mg': 1200, 'tembaga_mg': 900}),
        (80, float('inf'), {'serat_gram': 20, 'air_gram': 1400, 'vitc_mg': 75, 'retinol_mcg': 600, 'kalsium_mg': 1200, 'fosfor_mg': 700, 'zatbesi_mg': 8, 'kalium_mg': 4700, 'natrium_mg': 1000, 'tembaga_mg': 900})
    ]

    for min_age, max_age, limits in age_based_limits:
        if min_age <= umur <= max_age:
            batas_atas.update(limits)
            break

    kondisi_based_adjustments = {
        'hamil_trim_1': {'energi_kal': 180, 'karbohidrat_gram': 25, 'lemak_gram': 2.3, 'protein_gram': 1, 'serat_gram': 3, 'air_gram': 300, 'vitc_mg': 10, 'retinol_mcg': 300, 'kalsium_mg': 200, 'tembaga_mg': 100},
        'hamil_trim_2': {'energi_kal': 300, 'karbohidrat_gram': 40, 'lemak_gram': 2.3, 'protein_gram': 10, 'serat_gram': 4, 'air_gram': 300, 'vitc_mg': 10, 'retinol_mcg': 300, 'kalsium_mg': 200, 'zatbesi_mg': 9, 'tembaga_mg': 100},
        'hamil_trim_3': {'energi_kal': 300, 'karbohidrat_gram': 40, 'lemak_gram': 2.3, 'protein_gram': 30, 'serat_gram': 4, 'air_gram': 300, 'vitc_mg': 10, 'retinol_mcg': 300, 'kalsium_mg': 200, 'zatbesi_mg': 9, 'tembaga_mg': 100},
        'menyusui_6_awal': {'energi_kal': 330, 'karbohidrat_gram': 45, 'lemak_gram': 2.2, 'protein_gram': 20, 'serat_gram': 5, 'air_gram': 800, 'vitc_mg': 45, 'retinol_mcg': 350, 'kalsium_mg': 200, 'zatbesi_mg': 9, 'kalium_mg': 400, 'tembaga_mg': 100},
        'menyusui_6_kedua': {'energi_kal': 400, 'karbohidrat_gram': 55, 'lemak_gram': 2.2, 'protein_gram': 15, 'serat_gram': 5, 'air_gram': 650, 'vitc_mg': 45, 'retinol_mcg': 350, 'kalsium_mg': 200, 'zatbesi_mg': 9, 'kalium_mg': 400, 'tembaga_mg': 100}
    }

    if kondisi in kondisi_based_adjustments:
        for key, value in kondisi_based_adjustments[kondisi].items():
            batas_atas[key] += value
    
    print(batas_atas)
    print("===================================")

    # Bagi semua nilai di batas_atas dengan waktu_makan
    for key in batas_atas:
        batas_atas[key] /= waktu_makan

    return batas_atas

nutrisi = nutrition_need(24, 165, 65, "bisa jalan", "hamil_trim_1", 3)
print(nutrisi)
# Out:
# {'energi_kal': 2082.16, 'karbohidrat_gram': 310.324, 'lemak_gram': 55.13777777777778, 'protein_gram': 72.331, 'serat_gram': 35, 'air_gram': 2650, 'vitc_mg': 85, 'retinol_mcg': 900, 'kalsium_mg': 1200, 'fosfor_mg': 700, 'zatbesi_mg': 18, 'kalium_mg': 4700, 'natrium_mg': 1500, 'tembaga_mg': 1000}
# ...
# {'energi_kal': 694.0533333333333, 'karbohidrat_gram': 103.44133333333333, 'lemak_gram': 18.37925925925926, 'protein_gram': 24.110333333333333, 'serat_gram': 11.666666666666666, 'air_gram': 883.3333333333334, 'vitc_mg': 28.333333333333332, 'retinol_mcg': 300.0, 'kalsium_mg': 400.0, 'fosfor_mg': 233.33333333333334, 'zatbesi_mg': 6.0, 'kalium_mg': 1566.6666666666667, 'natrium_mg': 500.0, 'tembaga_mg': 333.3333333333333}

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# Membagi data menjadi set pelatihan dan pengujian
X_train, X_test = train_test_split(data_normalized, test_size=0.3, random_state=42)

# Fungsi untuk mengevaluasi model dengan berbagai nilai k
def evaluate_k_range(X_train, X_test, k_range):
    avg_distances = []
    for k in k_range:
        model = NearestNeighbors(n_neighbors=k, metric='cosine')
        model.fit(X_train)
        # Temukan tetangga terdekat untuk data uji
        distances, _ = model.kneighbors(X_test)
        avg_distances.append(np.mean(distances))
    return avg_distances

# Rentang nilai k yang ingin diuji
k_range = range(1, 31)
avg_distances = evaluate_k_range(X_train, X_test, k_range)

# Plotting nilai k versus rata-rata jarak tetangga terdekat
plt.figure(figsize=(10, 6))
plt.plot(k_range, avg_distances, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Average Distance to Nearest Neighbor')
plt.title('Determining the Optimal k')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

algo = "auto"
met = "eculidean"

# Baca data dari CSV
data = pd.read_csv("makanan13.csv")

# Drop kolom yang tidak diperlukan
data = data.drop(['id', 'kode', 'sumber', 'gambar', 'satuan'], axis=1)
data['jenis_pangan_encoded'] = pd.factorize(data['jenis_pangan'])[0] 

# Ubah nilai yang asalnya ',' menjadi '.'
numeric_cols = [ "jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
    "serat_gram", "abu_gram", "kalsium_mg", "fosfor_mg", "zatbesi_mg", "natrium_mg",
    "kalium_mg", "tembaga_mg", "seng_mg", "retinol_mcg", "thiamin_mg", "riboflavin_mg",
    "niasin_mg", "vitc_mg", "bdd"
]

print(len(numeric_cols))

data[numeric_cols] = data[numeric_cols].replace({',': '.'}, regex=True)
data[numeric_cols] = data[numeric_cols].astype(float)

# Normalisasi data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data[numeric_cols])

# Menggunakan Nearest Neighbors
model = NearestNeighbors(n_neighbors=6, algorithm="auto", metric="cosine")
model.fit(data_normalized)

# Fungsi untuk mendapatkan rekomendasi makanan
def get_recommendations(food_names, allergy_list):
    # Cari indeks makanan yang cocok dengan nama makanan yang diberikan
    food_indices = [data[data['nama_bahan'] == food_name].index[0] for food_name in food_names]
    
    print("Makanan tersebut berada di indeks ke-", food_indices)
    
    # Mencari tetangga terdekat
    distances, indices = model.kneighbors(data_normalized[food_indices])
    
    print("distances", distances)
    
    print("indices",indices)
    
    # Mendapatkan nama dan skor kemiripan makanan
    recommendations = []
    jarak = []
    for idx_list, dist_list in zip(indices, distances):
        for idx, dist in zip(idx_list, dist_list):
            if idx not in food_indices:
                recommendations.append(data.iloc[idx]['nama_bahan'])
                jarak.append(dist)
    
    return recommendations[:10], jarak[:10]  # Mengambil 10 teratas

# Contoh penggunaan
allergy_list = ['susu']  # Ganti dengan alergi yang dimiliki user
food_names = ['ayam daging segar']  # Ganti dengan makanan yang dimiliki user
recommendations, jarak = get_recommendations(food_names, allergy_list)
print(f"Rekomendasi makanan {algo} dan {met}:")
for idx, (food, score) in enumerate(zip(recommendations, jarak)):
    print(f"{idx+1}. {food} (distances: {score})")
# Out:
# 21
# Makanan tersebut berada di indeks ke- [646]
# distances [[0.         0.05729167 0.1057005  0.19679354 0.20669505 0.20764233]]
# indices [[646 645 653 143 650 129]]
# Rekomendasi makanan auto dan eculidean:
# 1. angsa daging segar (distances: 0.05729166776745542)
# 2. bebek (itik) daging segar (distances: 0.10570050412676102)
# 3. ham (distances: 0.19679354303973906)
# 4. babi daging kurus segar (distances: 0.20669505471140104)
# 5. bebek daging goreng (distances: 0.20764233339848648)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors

# Baca data dari CSV
data = pd.read_csv("resisData4.csv")

# Drop kolom yang tidak diperlukan
data = data.drop(['kode', 'sumber', 'gambar', 'satuan'], axis=1)
data['jenis_pangan_encoded'] = pd.factorize(data['jenis_pangan'])[0] 

# Ubah nilai yang asalnya ',' menjadi '.'
numeric_cols = [ "jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
    "serat_gram", "abu_gram", "kalsium_mg", "fosfor_mg", "zatbesi_mg", "natrium_mg",
    "kalium_mg", "tembaga_mg", "seng_mg", "retinol_mcg", "thiamin_mg", "riboflavin_mg",
    "niasin_mg", "vitc_mg", "bdd"
]

data[numeric_cols] = data[numeric_cols].replace({',': '.'}, regex=True)
data[numeric_cols] = data[numeric_cols].astype(float)

# Transform data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data[numeric_cols])

normalizedDataFrame = pd.DataFrame(data_normalized, columns=numeric_cols)

# Menggunakan Nearest Neighbors
model = NearestNeighbors(n_neighbors=4, metric='euclidean')
model.fit(data_normalized)

# Fungsi untuk mendapatkan rekomendasi makanan
def get_recommendations(food_names):
    # Cari indeks makanan yang cocok dengan nama makanan yang diberikan
    food_indices = [data[data['nama_bahan'] == food_name].index[0] for food_name in food_names]
    
    # Mencari tetangga terdekat
    distances, indices = model.kneighbors(data_normalized[food_indices])
    
    # Mendapatkan nama dan skor kemiripan makanan
    recommendations = []
    similarity_scores = []
    for idx_list, dist_list in zip(indices, distances):
        for idx, dist in zip(idx_list, dist_list):
            if idx not in food_indices:
                recommendations.append(data.iloc[idx]['nama_bahan'])
                similarity_scores.append(dist)  # Cosine similarity is 1 - cosine distance
    
    return recommendations[:10], similarity_scores[:10]  # Mengambil 10 teratas

# penggunaan
food_names = ['ayam daging segar']  # Ganti dengan makanan yang dimiliki user
recommendations, similarity_scores = get_recommendations(food_names)
print("Rekomendasi makanan:")
for idx, (food, score) in enumerate(zip(recommendations, similarity_scores)):
    print(f"{idx+1}. {food} (distance: {score})")

    
# Fungsi untuk menghitung akurasi
def calculate_accuracy(recommendations, actual):
    correct_predictions = sum([1 for rec in recommendations if rec in actual])
    return correct_predictions / len(recommendations)

# Daftar makanan untuk pengujian
food_list = data['nama_bahan'].unique().tolist()

# Daftar alergi, ganti sesuai kebutuhan
allergy_list = ['susu']

# List untuk menyimpan hasil pengujian
results = []

# Lakukan pengujian untuk setiap makanan
for food in food_list:
    recommendations, similarity_scores = get_recommendations([food])
    jarak = [similarity_scores]
    avg_jarak = np.mean(similarity_scores) if similarity_scores else 0
    results.append({
        'input_makanan': food,
        'hasil_rekomendasi': recommendations,
        'jarak': jarak,
        'ratarata_jarak': avg_jarak
    })

# Buat DataFrame dari hasil pengujian
results_df = pd.DataFrame(results)

results_df['id'] = range(1, len(results_df) + 1)

# # Simpan hasil pengujian ke dalam CSV
results_df.to_csv('hasil_pengujian_euclidean2.csv', index=False)

print("Pengujian selesai dan hasil disimpan ke 'hasil_pengujian_cosine.csv'.")
# Out:
# Rekomendasi makanan:
# 1. bebek (itik) daging segar (distance: 0.06024025096514942)
# 2. angsa daging segar (distance: 0.10503909145079351)
# 3. kacang tanah goreng (distance: 0.37734554662863773)
# Pengujian selesai dan hasil disimpan ke 'hasil_pengujian_cosine.csv'.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors

# Baca data dari CSV
data = pd.read_csv("resisData4.csv")

# Drop kolom yang tidak diperlukan
data = data.drop(['kode', 'sumber', 'gambar', 'satuan'], axis=1)
data['jenis_pangan_encoded'] = pd.factorize(data['jenis_pangan'])[0] 

# Ubah nilai yang asalnya ',' menjadi '.'
numeric_cols = [
    "jenis_pangan_encoded", "air_gram", "energi_kal", "protein_gram", "lemak_gram", "karbohidrat_gram",
    "serat_gram", "abu_gram", "kalsium_mg", "fosfor_mg", "zatbesi_mg", "natrium_mg",
    "kalium_mg", "tembaga_mg", "seng_mg", "retinol_mcg", "thiamin_mg", "riboflavin_mg",
    "niasin_mg", "vitc_mg", "bdd"
]

data[numeric_cols] = data[numeric_cols].replace({',': '.'}, regex=True)
data[numeric_cols] = data[numeric_cols].astype(float)

# Transform data
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data[numeric_cols])

normalizedDataFrame = pd.DataFrame(data_normalized, columns=numeric_cols)

# Menggunakan Nearest Neighbors
model = NearestNeighbors(n_neighbors=4, metric='euclidean')
model.fit(data_normalized)

# Fungsi untuk mendapatkan rekomendasi makanan
def get_recommendations(food_names):
    # Cari indeks makanan yang cocok dengan nama makanan yang diberikan
    food_indices = [data[data['nama_bahan'] == food_name].index[0] for food_name in food_names]
    
    # Mencari tetangga terdekat
    distances, indices = model.kneighbors(data_normalized[food_indices])
    
    # Mendapatkan nama dan skor kemiripan makanan
    recommendations = []
    similarity_scores = []
    for idx_list, dist_list in zip(indices, distances):
        for idx, dist in zip(idx_list, dist_list):
            if idx not in food_indices:
                recommendations.append(data.iloc[idx]['nama_bahan'])
                similarity_scores.append(dist)  # Euclidean distance
    
    return recommendations[:10], similarity_scores[:10]  # Mengambil 10 teratas

# Fungsi untuk menghitung akurasi
def calculate_accuracy(recommendations, actual):
    correct_predictions = sum([1 for rec in recommendations if rec in actual])
    return correct_predictions / len(recommendations)

# Daftar makanan untuk pengujian
food_list = data['nama_bahan'].unique().tolist()

# Daftar alergi, ganti sesuai kebutuhan
allergy_list = ['susu']

# List untuk menyimpan hasil pengujian
results = []

# Lakukan pengujian untuk setiap makanan
for food in food_list:
    recommendations, similarity_scores = get_recommendations([food])
    jarak = [similarity_scores]
    avg_jarak = np.mean(similarity_scores) if similarity_scores else 0
    
    # Menambahkan kolom jenis_pangan_input_makanan dan jenis_pangan_hasil_rekomendasi
    jenis_pangan_input_makanan = data[data['nama_bahan'] == food]['jenis_pangan'].values[0]
    jenis_pangan_hasil_rekomendasi = [data[data['nama_bahan'] == rec]['jenis_pangan'].values[0] for rec in recommendations]
    
    # Menentukan relevansi
    relevansi = int(all(pangan == jenis_pangan_input_makanan for pangan in jenis_pangan_hasil_rekomendasi))
    
    results.append({
        'input_makanan': food,
        'hasil_rekomendasi': recommendations,
        'jarak': jarak,
        'ratarata_jarak': avg_jarak,
        'jenis_pangan_input_makanan': jenis_pangan_input_makanan,
        'jenis_pangan_hasil_rekomendasi': jenis_pangan_hasil_rekomendasi,
        'relevansi': relevansi
    })

# Buat DataFrame dari hasil pengujian
results_df = pd.DataFrame(results)

results_df['id'] = range(1, len(results_df) + 1)

# Simpan hasil pengujian ke dalam CSV
results_df.to_csv('hasil_pengujian_euclidean3.csv', index=False)

print("Pengujian selesai dan hasil disimpan ke 'hasil_pengujian_euclidean3.csv'.")
# Out:
# Pengujian selesai dan hasil disimpan ke 'hasil_pengujian_euclidean3.csv'.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score

# Asumsikan df adalah DataFrame Anda
df = pd.read_csv('hasil_pengujian_euclidean3.csv')  # Ganti dengan nama file yang sesuai

# Fungsi untuk menghitung precision
def calculate_precision(row):
    relevant = sum(1 for pangan in row['jenis_pangan_hasil_rekomendasi'] 
                   if pangan == row['jenis_pangan_input_makanan'])
    return relevant / len(row['jenis_pangan_hasil_rekomendasi'])

# Hitung precision untuk setiap baris
df['precision'] = df.apply(calculate_precision, axis=1)

# Siapkan cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
precisions = []

for train_index, test_index in kf.split(df):
    df_train, df_test = df.iloc[train_index], df.iloc[test_index]
    
    # Hitung accuracy
    accuracy = accuracy_score(df_test['relevansi'], [1] * len(df_test))
    accuracies.append(accuracy)
    
    # Hitung rata-rata precision
    precision = df_test['precision'].mean()
    precisions.append(precision)

print(f"Average Accuracy: {np.mean(accuracies)}")
print(f"Average Precision: {np.mean(precisions)}")
# Out:
# Average Accuracy: 0.8322981366459627
# Average Precision: 0.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report

# Asumsikan df adalah DataFrame Anda
df = pd.read_csv('hasil_pengujian_euclidean3.csv')  # Ganti dengan nama file yang sesuai

# Fungsi untuk menentukan relevansi berdasarkan jenis pangan
def determine_relevance(row):
    return 1 if row['jenis_pangan_input_makanan'] in row['jenis_pangan_hasil_rekomendasi'] else 0

# Hitung relevansi untuk setiap baris
df['predicted_relevance'] = df.apply(determine_relevance, axis=1)

# Siapkan cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# List untuk menyimpan hasil setiap fold
all_reports = []

for train_index, test_index in kf.split(df):
    df_train, df_test = df.iloc[train_index], df.iloc[test_index]
    
    # Gunakan kolom 'relevansi' sebagai true labels dan 'predicted_relevance' sebagai prediksi
    y_true = df_test['relevansi']
    y_pred = df_test['predicted_relevance']
    
    # Hitung classification report
    report = classification_report(y_true, y_pred, output_dict=True)
    all_reports.append(report)

# Hitung rata-rata dari semua fold
avg_report = {}
for metric in ['precision', 'recall', 'f1-score', 'support']:
    avg_report[metric] = np.mean([fold['1'][metric] for fold in all_reports])

# Hitung accuracy rata-rata
avg_accuracy = np.mean([fold['accuracy'] for fold in all_reports])

# Tampilkan hasil
print("Average Metrics:")
print(f"Precision: {avg_report['precision']:.4f}")
print(f"Recall: {avg_report['recall']:.4f}")
print(f"F1-score: {avg_report['f1-score']:.4f}")
print(f"Support: {avg_report['support']:.0f}")
print(f"Accuracy: {avg_accuracy:.4f}")
print(classification_report(df_test['relevansi'], df_test['predicted_relevance']))
# Out:
# Average Metrics:
# Precision: 0.8600
# Recall: 1.0000
# F1-score: 0.9246
# Support: 268
# Accuracy: 0.8646
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.34        59
#            1       0.85      1.00      0.92       263
#
#     accuracy                           0.85       322
#    macro avg       0.92      0.60      0.63       322
# weighted avg       0.88      0.85      0.81       322
